# %%
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import math
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv

# %% [markdown]
# ### 1. Samung_Electronics.csv은 날짜 별 삼성전자 주식 데이터이다. 해당 csv 파일의 'Close'열만 추출하여 stock_data에 저장하시오.

# %%
# 코드 작성
import pandas as pd

stock_data = pd.read_csv('Samsung_Electronics.csv').values
stock_data = stock_data[:,4]

print(stock_data)
# Out:
# [69500 69700 71500 72900 71700 73900 72900 73400 73800 73800 73800 73300
#  73000 73000 72300 73900 77800 78700 78300 81000 83000 83900 82200 82900
#  88800 91000 90600 89700 89700 88000 85000 87000 87200 88100 86800 89400
#  86700 85600 83700 82000 83000 84400 84600 82500 83500 83000 82700 81600
#  84200 84900 83200 82100 82600 82200 82000 82000 85300 82500 83600 84000
#  82400 82100 82000 81400 80900 82000 82800 81800 82800 82300 82900 81900
#  82000 81800 81000 81200 81500 81600 82200 81400 82900 84800 85400 86000
#  85600 84700 83600 83200 84000 84000 84100 83900 83300 83900 82600 82400
#  82800 83500 82900 82100 81700 81500 81700 82600 82300 81900 83200 81200
#  80000 78500 80100 79600 79600 79500 80100 79700 79900 79800 79600 80100
#  80500 80600 80800 82800 82200 81900 81900 81100 81000 81000 80500 80900
#  81800 80900 80500 79900 80000 80100 81200 81600 81900 81000 80700 80100
#  80000 80400 81200 80800 79900 79400 79700 79800 79500 80600 79800 79000
#  79000 78500 79700 79300 78800 78500 79200 79000 78500 79300 81400 82900
#  82100 81500 81500 80200 78500 77000 74400 74200 73900 73100 72700 73300
#  75600 75700 74600 74300 74600 76700 76800 76000 76600 77300 76100 76300
#  75300 75300 76300 76600 77000 76100 77200 77400 77300 77700 76300 74100
#  74100 73200 72200 71300 71600 71500 69000 68800 69400 70100 70200 70600
#  70300 70200 70400 70200 71100 70100 70700 69800 69900 71500 70400 70600
#  70200 70600 70500 70200 69900 70600 71400 71300 70700 70200 71200 74900
#  75300 74800 73700 72300 72300 71300 74400 75800]

# %% [markdown]
# ### 2. stock_data의 범위가 0~5가 되도록 크기를 조절한 후, StockData에 저장하시오.

# %%
# 코드 작성
StockData =

# %% [markdown]
# ### 3. train_data(학습데이터)와 test_data(테스트데이터)를 75:25의 비율로 분리한 후, 각 데이터의 수를 확인하시오.

# %%
# 코드 작성

# %% [markdown]
# ### 4. 7일 간의 데이터로 다음 날의 주식 값을 예측할 수 있는 데이터 형태로 변형하시오. (x: 7일 간 주식 값, y: 다음 날 주식 값)

# %% [markdown]
# - train_x, train_y, test_x, test_y로 분리하시오.

# %%
# 코드 작성

# %% [markdown]
# ### 5. train_x, train_y, test_x, test_y의 행과 열의 수(shape)를 확인하고, x와 y가 각각 어떠한 데이터를 의미하는지 간단히 서술하시오.

# %%
# 코드 작성

# %% [markdown]
# ### 6. RNN model에 적용할 수 있도록 train_x과 test_x를 3D array로 변형하시오.

# %% [markdown]
# - 3D로 변형한 데이터를 각각 trainX, testX에 저장하시오.

# %%
# 코드 작성

# %% [markdown]
# ### 7. 아래 코드를 완성하여 RNN model을 구성하시오.

# %%
# 코드 완성
model = Sequential([
                    SimpleRNN(),
                    Dense(),
                    ])

# %%
model.compile(optimizer = 'adam', loss = 'mse')

# %% [markdown]
# ### 8. batch size은 1, epochs은 100으로 설정하고, 위의 학습데이터를 적용하여 RNN model을 학습하시오.

# %%
# 코드 작성

# %% [markdown]
# ### 9. test dat를 이용하여 RNN model의 성능을 평가하시오.
# - 0~5 사이의 범위가 아닌 기존 데이터의 범위로 역변환하여 mean squared error로 성능을 평가하시오.

# %%
# 코드 작성

# %% [markdown]
# ### 10. 실제 데이터, 학습데이터 예측 결과, 테스트데이터 예측 결과를 하나의 차트에 서로 다른 색상으로 line plot을 그리고, 각각의 색상이 실제 데이터값 / 학습데이터 예측결과 / 테스트 데이터 예측 결과 중 어떠한 데이터를 의미하는지 작성하시오.
# - 반드시, 0~5 사이의 범위가 아닌 기존 데이터의 범위의 값으로 시각화하시오.
