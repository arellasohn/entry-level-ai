# %% [markdown]
# ## 1. Gradient descent에 대해 간단히 설명하시오.

# %% [markdown]
# [작성]
# 함수 값이 낮아지는 방향으로 독립 변수 값을 변형시켜가면서 최종적으로는 최소 함수 값을 갖도록 하는 독립 변수 값을 찾는 방법입니다.

# %% [markdown]
# ## 2. Classification과 regression의 차이점을 간단히 서술하시오.

# %% [markdown]
# [작성]
# classification의 경우 남성 vs 여성, 참 vs 거짓 등의 discrete한 value를 예측/분류하는데 사용되고, regression은 가격, 급여, 나이 등과 같은 continuous한 value를 예측하는데 사용된다는 점이다.

# %% [markdown]
# ## 3. Perceptron의 한계에 대해 간단히 설명하시오.

# %% [markdown]
# [작성]
# 직선 하나로 나눈 영역만 표현할 수 있다는 한계가 있다.

# %% [markdown]
# ## 4. 위조지폐와 정상지폐를 구분하는 인공지능 모델에서 위조지폐를 positive data, 정상지폐를 negative data라고 할 때, False positive는 어떠한 경우를 의미하는가?

# %% [markdown]
# [작성]
# 위조지폐로 판별되어야 할 지폐가 정상지폐로 판별되는 경우이다.

# %% [markdown]
# ## 5. 4번 인공지능 모델에서 precision은 크지만, recall이 낮은 경우는 어떠한 경우인가?

# %% [markdown]
# [작성]
# 확실하지 않은 경우에 대해서는 아예 예측을 하지 않고 보류하여, 매우 적은 경우의 수만 소극적으로 예측하는 경우이다.
