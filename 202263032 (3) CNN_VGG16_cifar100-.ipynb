# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.datasets import fashion_mnist, cifar100
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt

# %%
# fashion_mnist dataset 로드
(x_train, y_train), (x_test, y_test) = cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 2s 0us/step

# %% [markdown]
# ### 1. cifar100를 이용하여 VGG16 기반 CNN model을 학습하여 생성하시오.
# - VGG16은 ResNet50와 동일한 방식으로 사용함
# - epoch은 10 내외로 설정하되, 이 외의 파라미터는 자유롭게 선정하시오.

# %%
# 코드 작성
# 학습 시, 학습데이터의 30%를 검증(validation) 데이터로 이용하시오.
model = Sequential([
    Conv2D(filters=32,kernel_size=(3,3),strides=(1,1),activation='relu',input_shape=(28,28,1)),
    MaxPooling2D(pool_size=(2,2),strides=(2,2)),
    Flatten(),
    Dense(units=512,activation='relu'),
    Dense(units=10,activation='softmax')
])

mnist_model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['acc'])

mnist_result = mnist_model.fit(x_train, y_train, epochs=ep, batch_size=batch, validation_split=val_ratio)

# %% [markdown]
# ### 2. VGG16, ResNet50 등 미리 구현된 layer를 활용하는 transfer learning에 대해 간단히 설명하시오.

# %% [markdown]
# [정답] '이미지 분류' 문제를 해결하는데 사용했던 네트워크(DNN;Deep Neural Network)를 다른 데이터셋 혹은 다른 문제(task)에 적용시켜 푸는 것입니다.

# %% [markdown]
# ### 3. 생성된 model에 x_test 이미지를 적용했을 때의 정확도를 구하시오.

# %%
# 코드 작성
# 정확도: ??

# %% [markdown]
# ### 4. 학습 과정의 epoch에 대한 training data 및 validation 데이터의 loss와 accuracy 변화를 차트로 그리시오.
